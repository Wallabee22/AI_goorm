# %%
import pandas as pd

# %%
train = pd.read_csv("./california/california_housing_train.csv")
test  = pd.read_csv("./california/california_housing_test.csv")

train.shape, test.shape
# Out:
# ((17000, 9), (3000, 9))

# %%
### 데이터 자료형 확인하기
### 앞의 데이터 5행 확인
### 뒤의 데이터 5행 확인
### 데이터의 요약값 확인하기
### 데이터의 결측치 확인하기
train.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0

# %%
train.tail()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
#        population  households  median_income  median_house_value
# 16995       907.0       369.0         2.3571            111400.0
# 16996      1194.0       465.0         2.5179             79000.0
# 16997      1244.0       456.0         3.0313            103600.0
# 16998      1298.0       478.0         1.9797             85800.0
# 16999       806.0       270.0         3.0147             94600.0

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17000 entries, 0 to 16999
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           17000 non-null  float64
#  1   latitude            17000 non-null  float64
#  2   housing_median_age  17000 non-null  float64
#  3   total_rooms         17000 non-null  float64
#  4   total_bedrooms      17000 non-null  float64
#  5   population          17000 non-null  float64
#  6   households          17000 non-null  float64
#  7   median_income       17000 non-null  float64
#  8   median_house_value  17000 non-null  float64
# dtypes: float64(9)
# memory usage: 1.2 MB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           3000 non-null   float64
#  1   latitude            3000 non-null   float64
#  2   housing_median_age  3000 non-null   float64
#  3   total_rooms         3000 non-null   float64
#  4   total_bedrooms      3000 non-null   float64
#  5   population          3000 non-null   float64
#  6   households          3000 non-null   float64
#  7   median_income       3000 non-null   float64
#  8   median_house_value  3000 non-null   float64
# dtypes: float64(9)
# memory usage: 211.1 KB

# %%
### 어떤 컬럼명을 가지고 있을까?
print(test.columns) 
print(train.columns)
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value'],
#       dtype='object')
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value'],
#       dtype='object')

# %%
### 데이터는 어떤 자료형을 갖는가?
print(test.dtypes) 
print()
print(train.dtypes)
# Out:
# longitude             float64
# latitude              float64
# housing_median_age    float64
# total_rooms           float64
# total_bedrooms        float64
# population            float64
# households            float64
# median_income         float64
# median_house_value    float64
# dtype: object
#
# longitude             float64
# latitude              float64
# housing_median_age    float64
# total_rooms           float64
# total_bedrooms        float64
# population            float64
# households            float64
# median_income         float64
# median_house_value    float64
# dtype: object

# %%
type(test.dtypes)
# Out:
# pandas.core.series.Series

# %%
test.dtypes.index
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value'],
#       dtype='object')

# %%
### 데이터는 어떤 값들을 갖는가?
train.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  17000.000000  17000.000000        17000.000000  17000.000000
# mean    -119.562108     35.625225           28.589353   2643.664412
# std        2.005166      2.137340           12.586937   2179.947071
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.790000     33.930000           18.000000   1462.000000
# 50%     -118.490000     34.250000           29.000000   2127.000000
# 75%     -118.000000     37.720000           37.000000   3151.250000
# max     -114.310000     41.950000           52.000000  37937.000000
#
#        total_bedrooms    population    households  median_income  \
# count    17000.000000  17000.000000  17000.000000   17000.000000
# mean       539.410824   1429.573941    501.221941       3.883578
# std        421.499452   1147.852959    384.520841       1.908157
# min          1.000000      3.000000      1.000000       0.499900
# 25%        297.000000    790.000000    282.000000       2.566375
# 50%        434.000000   1167.000000    409.000000       3.544600
# 75%        648.250000   1721.000000    605.250000       4.767000
# max       6445.000000  35682.000000   6082.000000      15.000100
#
#        median_house_value
# count        17000.000000
# mean        207300.912353
# std         115983.764387
# min          14999.000000
# 25%         119400.000000
# 50%         180400.000000
# 75%         265000.000000
# max         500001.000000

# %%
### 데이터는 어떤 값들을 갖는가?
test.describe()
# Out:
#          longitude    latitude  housing_median_age   total_rooms  \
# count  3000.000000  3000.00000         3000.000000   3000.000000
# mean   -119.589200    35.63539           28.845333   2599.578667
# std       1.994936     2.12967           12.555396   2155.593332
# min    -124.180000    32.56000            1.000000      6.000000
# 25%    -121.810000    33.93000           18.000000   1401.000000
# 50%    -118.485000    34.27000           29.000000   2106.000000
# 75%    -118.020000    37.69000           37.000000   3129.000000
# max    -114.490000    41.92000           52.000000  30450.000000
#
#        total_bedrooms    population  households  median_income  \
# count     3000.000000   3000.000000  3000.00000    3000.000000
# mean       529.950667   1402.798667   489.91200       3.807272
# std        415.654368   1030.543012   365.42271       1.854512
# min          2.000000      5.000000     2.00000       0.499900
# 25%        291.000000    780.000000   273.00000       2.544000
# 50%        437.000000   1155.000000   409.50000       3.487150
# 75%        636.000000   1742.750000   597.25000       4.656475
# max       5419.000000  11935.000000  4930.00000      15.000100
#
#        median_house_value
# count          3000.00000
# mean         205846.27500
# std          113119.68747
# min           22500.00000
# 25%          121200.00000
# 50%          177650.00000
# 75%          263975.00000
# max          500001.00000

# %%
# 세대별 방의 개수
train['room_household'] = train['total_rooms'] / train['households']
test['room_household'] = test['total_rooms'] / test['households']
train
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
#        population  households  median_income  median_house_value  \
# 0          1015.0       472.0         1.4936             66900.0
# 1          1129.0       463.0         1.8200             80100.0
# 2           333.0       117.0         1.6509             85700.0
# 3           515.0       226.0         3.1917             73400.0
# 4           624.0       262.0         1.9250             65500.0
# ...           ...         ...            ...                 ...
# 16995       907.0       369.0         2.3571            111400.0
# 16996      1194.0       465.0         2.5179             79000.0
# 16997      1244.0       456.0         3.0313            103600.0
# 16998      1298.0       478.0         1.9797             85800.0
# 16999       806.0       270.0         3.0147             94600.0
#
#        room_household
# 0           11.889831
# 1           16.522678
# 2            6.153846
# 3            6.641593
# 4            5.549618
# ...               ...
# 16995        6.008130
# 16996        5.051613
# 16997        5.870614
# 16998        5.589958
# 16999        6.740741
#
# [17000 rows x 10 columns]

# %%
train.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  17000.000000  17000.000000        17000.000000  17000.000000
# mean    -119.562108     35.625225           28.589353   2643.664412
# std        2.005166      2.137340           12.586937   2179.947071
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.790000     33.930000           18.000000   1462.000000
# 50%     -118.490000     34.250000           29.000000   2127.000000
# 75%     -118.000000     37.720000           37.000000   3151.250000
# max     -114.310000     41.950000           52.000000  37937.000000
#
#        total_bedrooms    population    households  median_income  \
# count    17000.000000  17000.000000  17000.000000   17000.000000
# mean       539.410824   1429.573941    501.221941       3.883578
# std        421.499452   1147.852959    384.520841       1.908157
# min          1.000000      3.000000      1.000000       0.499900
# 25%        297.000000    790.000000    282.000000       2.566375
# 50%        434.000000   1167.000000    409.000000       3.544600
# 75%        648.250000   1721.000000    605.250000       4.767000
# max       6445.000000  35682.000000   6082.000000      15.000100
#
#        median_house_value  room_household
# count        17000.000000    17000.000000
# mean        207300.912353        5.439044
# std         115983.764387        2.539196
# min          14999.000000        0.846154
# 25%         119400.000000        4.445275
# 50%         180400.000000        5.236106
# 75%         265000.000000        6.058097
# max         500001.000000      141.909091

# %%
# 세대별 침실의 개수
train['bedrooms_household'] = train['total_bedrooms'] / train['households']
test['bedrooms_household'] = test['total_bedrooms'] / test['households']

# 세대별 인구수
train['population_household'] = train['population'] / train['households']
test['population_household'] = test['population'] / test['households']

train.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value  room_household  \
# 0      1015.0       472.0         1.4936             66900.0       11.889831
# 1      1129.0       463.0         1.8200             80100.0       16.522678
# 2       333.0       117.0         1.6509             85700.0        6.153846
# 3       515.0       226.0         3.1917             73400.0        6.641593
# 4       624.0       262.0         1.9250             65500.0        5.549618
#
#    bedrooms_household  population_household
# 0            2.718220              2.150424
# 1            4.105832              2.438445
# 2            1.487179              2.846154
# 3            1.491150              2.278761
# 4            1.244275              2.381679

# %%
test.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
#
#    population  households  median_income  median_house_value  room_household  \
# 0      1537.0       606.0         6.6085            344700.0        6.410891
# 1       809.0       277.0         3.5990            176500.0        5.451264
# 2      1484.0       495.0         5.7934            270500.0        7.250505
# 3        49.0        11.0         6.1359            330000.0        6.090909
# 4       850.0       237.0         2.9375             81700.0        5.236287
#
#    bedrooms_household  population_household
# 0            1.090759              2.536304
# 1            1.119134              2.920578
# 2            1.024242              2.997980
# 3            1.363636              4.454545
# 4            1.029536              3.586498

# %%
train.corr()['median_house_value']
# Out:
# longitude              -0.044982
# latitude               -0.144917
# housing_median_age      0.106758
# total_rooms             0.130991
# total_bedrooms          0.045783
# population             -0.027850
# households              0.061031
# median_income           0.691871
# median_house_value      1.000000
# room_household          0.150081
# bedrooms_household     -0.045668
# population_household   -0.042764
# Name: median_house_value, dtype: float64

# %%
train
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
#        population  households  median_income  median_house_value  \
# 0          1015.0       472.0         1.4936             66900.0
# 1          1129.0       463.0         1.8200             80100.0
# 2           333.0       117.0         1.6509             85700.0
# 3           515.0       226.0         3.1917             73400.0
# 4           624.0       262.0         1.9250             65500.0
# ...           ...         ...            ...                 ...
# 16995       907.0       369.0         2.3571            111400.0
# 16996      1194.0       465.0         2.5179             79000.0
# 16997      1244.0       456.0         3.0313            103600.0
# 16998      1298.0       478.0         1.9797             85800.0
# 16999       806.0       270.0         3.0147             94600.0
#
#        room_household  bedrooms_household  population_household
# 0           11.889831            2.718220              2.150424
# 1           16.522678            4.105832              2.438445
# 2            6.153846            1.487179              2.846154
# 3            6.641593            1.491150              2.278761
# 4            5.549618            1.244275              2.381679
# ...               ...                 ...                   ...
# 16995        6.008130            1.067751              2.457995
# 16996        5.051613            1.135484              2.567742
# 16997        5.870614            1.164474              2.728070
# 16998        5.589958            1.154812              2.715481
# 16999        6.740741            1.111111              2.985185
#
# [17000 rows x 12 columns]

# %%
train['total_bedrooms'].describe()
# Out:
# count    17000.000000
# mean       539.410824
# std        421.499452
# min          1.000000
# 25%        297.000000
# 50%        434.000000
# 75%        648.250000
# max       6445.000000
# Name: total_bedrooms, dtype: float64

# %%
# 2-5 침실이 가장 많은 위치는 어디인가?
# 2-6 중위 소득이 가장 높은 지역은 어디일까?

# %%
train.loc[ train['total_bedrooms']==6445 , : ]
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 12772    -121.79     36.64                11.0      32627.0          6445.0
#
#        population  households  median_income  median_house_value  \
# 12772     28566.0      6082.0         2.3087            118800.0
#
#        room_household  bedrooms_household  population_household
# 12772        5.364518            1.059684               4.69681

# %%
# 2-5-1 침실이 3000개 이상 지역은 어디인가?
train.loc[ train['total_bedrooms'] >= 5000 , : ]
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2871     -117.74     33.89                 4.0      37937.0          5471.0
# 2969     -117.78     34.03                 8.0      32054.0          5290.0
# 12772    -121.79     36.64                11.0      32627.0          6445.0
#
#        population  households  median_income  median_house_value  \
# 2871      16122.0      5189.0         7.4947            366300.0
# 2969      15507.0      5050.0         6.0191            253900.0
# 12772     28566.0      6082.0         2.3087            118800.0
#
#        room_household  bedrooms_household  population_household
# 2871         7.311043            1.054346              3.106957
# 2969         6.347327            1.047525              3.070693
# 12772        5.364518            1.059684              4.696810

# %%
sel = ['total_rooms', 'total_bedrooms', 'population']
temp_train = train[ sel  ]

print("데이터 가공 셋의 크기 : ", temp_train.shape)
print("데이터 가공 셋의 일부 : ")
print(temp_train.head())
# Out:
# 데이터 가공 셋의 크기 :  (17000, 3)
# 데이터 가공 셋의 일부 :
#    total_rooms  total_bedrooms  population
# 0       5612.0          1283.0      1015.0
# 1       7650.0          1901.0      1129.0
# 2        720.0           174.0       333.0
# 3       1501.0           337.0       515.0
# 4       1454.0           326.0       624.0

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10,10))

plt.subplot(3,1,1) 
sns.boxplot(x="total_rooms", data=temp_train)

plt.subplot(3,1,2) 
sns.boxplot(x="total_bedrooms", data=temp_train)

plt.subplot(3,1,3) 
sns.boxplot(x="population", data=temp_train)
# Out:
# <AxesSubplot:xlabel='population'>

# %%
plt.figure(figsize=(10,10))

plt.subplot(3,3,1) 
sns.boxplot(x="total_rooms", data=train)
plt.subplot(3,3,2) 
sns.boxplot(x="total_bedrooms", data=train)
plt.subplot(3,3,3) 
sns.boxplot(x="population", data=train)  

plt.subplot(3,3,4) 
sns.boxplot(x="longitude", data=train)
plt.subplot(3,3,5) 
sns.boxplot(x="latitude", data=train)
plt.subplot(3,3,6) 
sns.boxplot(x="households", data=train)  

plt.subplot(3,3,7) 
sns.boxplot(x="median_income", data=train)
plt.subplot(3,3,8) 
sns.boxplot(x="median_house_value", data=train)
# Out:
# <AxesSubplot:xlabel='median_house_value'>

# %%
## 두 컬럼 선택 8열, 9열
temp03 = train.iloc[:,  [7, 8] ]
print( temp03.head() )

print()

temp03 = train.iloc[:,  [-2, -1] ]
print( temp03.head() )
# Out:
#    median_income  median_house_value
# 0         1.4936             66900.0
# 1         1.8200             80100.0
# 2         1.6509             85700.0
# 3         3.1917             73400.0
# 4         1.9250             65500.0
#
#    bedrooms_household  population_household
# 0            2.718220              2.150424
# 1            4.105832              2.438445
# 2            1.487179              2.846154
# 3            1.491150              2.278761
# 4            1.244275              2.381679

# %%
train.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value  room_household  \
# 0      1015.0       472.0         1.4936             66900.0       11.889831
# 1      1129.0       463.0         1.8200             80100.0       16.522678
# 2       333.0       117.0         1.6509             85700.0        6.153846
# 3       515.0       226.0         3.1917             73400.0        6.641593
# 4       624.0       262.0         1.9250             65500.0        5.549618
#
#    bedrooms_household  population_household
# 0            2.718220              2.150424
# 1            4.105832              2.438445
# 2            1.487179              2.846154
# 3            1.491150              2.278761
# 4            1.244275              2.381679

# %%
train['total_rooms'].describe()
# Out:
# count    17000.000000
# mean      2643.664412
# std       2179.947071
# min          2.000000
# 25%       1462.000000
# 50%       2127.000000
# 75%       3151.250000
# max      37937.000000
# Name: total_rooms, dtype: float64

# %%
# A1 : 75~100  3152 ~ 
# A2 : 50~75   2128 ~ 3151
# A3 : 25~50   1463 ~ 2127
# A4 : 0~25    ~1462

# %%
train.loc[ train['total_rooms']>= 3152 , "total_rooms_level"] = 1
train.loc[ (train['total_rooms']> 2127) & (train['total_rooms'] <= 3151) , "total_rooms_level"] = 2
train.loc[ (train['total_rooms']> 1462) & (train['total_rooms'] <= 2127) , "total_rooms_level"] = 3
train.loc[ train['total_rooms'] <= 1462 , "total_rooms_level"] = 4
train
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
#        population  households  median_income  median_house_value  \
# 0          1015.0       472.0         1.4936             66900.0
# 1          1129.0       463.0         1.8200             80100.0
# 2           333.0       117.0         1.6509             85700.0
# 3           515.0       226.0         3.1917             73400.0
# 4           624.0       262.0         1.9250             65500.0
# ...           ...         ...            ...                 ...
# 16995       907.0       369.0         2.3571            111400.0
# 16996      1194.0       465.0         2.5179             79000.0
# 16997      1244.0       456.0         3.0313            103600.0
# 16998      1298.0       478.0         1.9797             85800.0
# 16999       806.0       270.0         3.0147             94600.0
#
#        room_household  bedrooms_household  population_household  \
# 0           11.889831            2.718220              2.150424
# 1           16.522678            4.105832              2.438445
# 2            6.153846            1.487179              2.846154
# 3            6.641593            1.491150              2.278761
# 4            5.549618            1.244275              2.381679
# ...               ...                 ...                   ...
# 16995        6.008130            1.067751              2.457995
# 16996        5.051613            1.135484              2.567742
# 16997        5.870614            1.164474              2.728070
# 16998        5.589958            1.154812              2.715481
# 16999        6.740741            1.111111              2.985185
#
#        total_rooms_level
# 0                    1.0
# 1                    1.0
# 2                    4.0
# 3                    3.0
# 4                    4.0
# ...                  ...
# 16995                2.0
# 16996                2.0
# 16997                2.0
# 16998                2.0
# 16999                3.0
#
# [17000 rows x 13 columns]

# %%
train
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
#        population  households  median_income  median_house_value  \
# 0          1015.0       472.0         1.4936             66900.0
# 1          1129.0       463.0         1.8200             80100.0
# 2           333.0       117.0         1.6509             85700.0
# 3           515.0       226.0         3.1917             73400.0
# 4           624.0       262.0         1.9250             65500.0
# ...           ...         ...            ...                 ...
# 16995       907.0       369.0         2.3571            111400.0
# 16996      1194.0       465.0         2.5179             79000.0
# 16997      1244.0       456.0         3.0313            103600.0
# 16998      1298.0       478.0         1.9797             85800.0
# 16999       806.0       270.0         3.0147             94600.0
#
#        room_household  bedrooms_household  population_household  \
# 0           11.889831            2.718220              2.150424
# 1           16.522678            4.105832              2.438445
# 2            6.153846            1.487179              2.846154
# 3            6.641593            1.491150              2.278761
# 4            5.549618            1.244275              2.381679
# ...               ...                 ...                   ...
# 16995        6.008130            1.067751              2.457995
# 16996        5.051613            1.135484              2.567742
# 16997        5.870614            1.164474              2.728070
# 16998        5.589958            1.154812              2.715481
# 16999        6.740741            1.111111              2.985185
#
#        total_rooms_level
# 0                    1.0
# 1                    1.0
# 2                    4.0
# 3                    3.0
# 4                    4.0
# ...                  ...
# 16995                2.0
# 16996                2.0
# 16997                2.0
# 16998                2.0
# 16999                3.0
#
# [17000 rows x 13 columns]

# %% [markdown]
# ### total_bedrooms에 대한 구간 나누기

# %%
train['total_bedrooms'].describe()
# Out:
# count    17000.000000
# mean       539.410824
# std        421.499452
# min          1.000000
# 25%        297.000000
# 50%        434.000000
# 75%        648.250000
# max       6445.000000
# Name: total_bedrooms, dtype: float64

# %%
## 1그룹 : 648~
## 2그룹 : 435~648
## 3그룹 : 298~434
## 4그룹 : 1 ~ 297

train.loc[ train['total_bedrooms']>= 648 , "total_bedrooms_level"] = 1
train.loc[ (train['total_bedrooms']> 434) & (train['total_bedrooms'] <= 648) , "total_bedrooms_level"] = 2
train.loc[ (train['total_bedrooms']> 297) & (train['total_bedrooms'] <= 434) , "total_bedrooms_level"] = 3
train.loc[ (train['total_bedrooms']<= 297) , "total_bedrooms_level"] = 4

# %%
train['median_income'].describe()
# Out:
# count    17000.000000
# mean         3.883578
# std          1.908157
# min          0.499900
# 25%          2.566375
# 50%          3.544600
# 75%          4.767000
# max         15.000100
# Name: median_income, dtype: float64

# %%
# 1구간 : ~ 0.5
# 2구간 : 0.5~1 만달러
# 3구간 : 1.0~1.5
# 4구간 : 1.5~2.0
# 5구간 : 2.0~2.5
# 6구간 : 2.5~3.0
# 7구간 : 3.0~3.5
# 8구간 : 3.5~4.0
# 9구간 : 4.0~4.5
#10구간 : 4.5~

train.loc[ train['median_income']>= 4.5 , "median_income_level"] = 10
train.loc[ (train['median_income']> 4.0) & (train['median_income'] <= 4.5) , "median_income_level"] = 9
train.loc[ (train['median_income']> 3.5) & (train['median_income'] <= 4.0) , "median_income_level"] = 8
train.loc[ (train['median_income']> 3.0) & (train['median_income'] <= 3.5) , "median_income_level"] = 7
train.loc[ (train['median_income']> 2.5) & (train['median_income'] <= 3.0) , "median_income_level"] = 6
train.loc[ (train['median_income']> 2.0) & (train['median_income'] <= 2.5) , "median_income_level"] = 5
train.loc[ (train['median_income']> 1.5) & (train['median_income'] <= 2.0) , "median_income_level"] = 4
train.loc[ (train['median_income']> 1.0) & (train['median_income'] <= 1.5) , "median_income_level"] = 3
train.loc[ (train['median_income']> 0.5) & (train['median_income'] <= 1.0) , "median_income_level"] = 2
train.loc[ (train['median_income']<= 0.5) , "median_income_level"] = 1

train
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
#        population  households  median_income  median_house_value  \
# 0          1015.0       472.0         1.4936             66900.0
# 1          1129.0       463.0         1.8200             80100.0
# 2           333.0       117.0         1.6509             85700.0
# 3           515.0       226.0         3.1917             73400.0
# 4           624.0       262.0         1.9250             65500.0
# ...           ...         ...            ...                 ...
# 16995       907.0       369.0         2.3571            111400.0
# 16996      1194.0       465.0         2.5179             79000.0
# 16997      1244.0       456.0         3.0313            103600.0
# 16998      1298.0       478.0         1.9797             85800.0
# 16999       806.0       270.0         3.0147             94600.0
#
#        room_household  bedrooms_household  population_household  \
# 0           11.889831            2.718220              2.150424
# 1           16.522678            4.105832              2.438445
# 2            6.153846            1.487179              2.846154
# 3            6.641593            1.491150              2.278761
# 4            5.549618            1.244275              2.381679
# ...               ...                 ...                   ...
# 16995        6.008130            1.067751              2.457995
# 16996        5.051613            1.135484              2.567742
# 16997        5.870614            1.164474              2.728070
# 16998        5.589958            1.154812              2.715481
# 16999        6.740741            1.111111              2.985185
#
#        total_rooms_level  total_bedrooms_level  median_income_level
# 0                    1.0                   1.0                  3.0
# 1                    1.0                   1.0                  4.0
# 2                    4.0                   4.0                  4.0
# 3                    3.0                   3.0                  7.0
# 4                    4.0                   3.0                  4.0
# ...                  ...                   ...                  ...
# 16995                2.0                   3.0                  5.0
# 16996                2.0                   2.0                  6.0
# 16997                2.0                   2.0                  7.0
# 16998                2.0                   2.0                  4.0
# 16999                3.0                   3.0                  7.0
#
# [17000 rows x 15 columns]

# %%
import seaborn as sns

sns.barplot(x='total_rooms_level', y='median_house_value', data=train )
# Out:
# <AxesSubplot:xlabel='total_rooms_level', ylabel='median_house_value'>

# %%
import seaborn as sns

sns.barplot(x='total_bedrooms_level', y='median_house_value', data=train )
# Out:
# <AxesSubplot:xlabel='total_bedrooms_level', ylabel='median_house_value'>

# %%
sns.barplot(x='median_income_level', y='median_house_value', data=train )
# Out:
# <AxesSubplot:xlabel='median_income_level', ylabel='median_house_value'>

# %%
train.corr()
# Out:
#                       longitude  latitude  housing_median_age  total_rooms  \
# longitude              1.000000 -0.925208           -0.114250     0.047010
# latitude              -0.925208  1.000000            0.016454    -0.038773
# housing_median_age    -0.114250  0.016454            1.000000    -0.360984
# total_rooms            0.047010 -0.038773           -0.360984     1.000000
# total_bedrooms         0.071802 -0.069373           -0.320434     0.928403
# population             0.101674 -0.111261           -0.295890     0.860170
# households             0.059628 -0.074902           -0.302754     0.919018
# median_income         -0.015485 -0.080303           -0.115932     0.195383
# median_house_value    -0.044982 -0.144917            0.106758     0.130991
# room_household        -0.032894  0.110017           -0.146234     0.125385
# bedrooms_household     0.008413  0.073101           -0.074101     0.024485
# population_household   0.028951 -0.032784            0.006274    -0.035327
# total_rooms_level     -0.019190  0.022667            0.332183    -0.697931
# total_bedrooms_level  -0.055218  0.062550            0.282761    -0.653019
# median_income_level   -0.012903 -0.088400           -0.142548     0.224124
#
#                       total_bedrooms  population  households  median_income  \
# longitude                   0.071802    0.101674    0.059628      -0.015485
# latitude                   -0.069373   -0.111261   -0.074902      -0.080303
# housing_median_age         -0.320434   -0.295890   -0.302754      -0.115932
# total_rooms                 0.928403    0.860170    0.919018       0.195383
# total_bedrooms              1.000000    0.881169    0.980920      -0.013495
# population                  0.881169    1.000000    0.909247      -0.000638
# households                  0.980920    0.909247    1.000000       0.007644
# median_income              -0.013495   -0.000638    0.007644       1.000000
# median_house_value          0.045783   -0.027850    0.061031       0.691871
# room_household             -0.006480   -0.074806   -0.084505       0.317311
# bedrooms_household          0.040284   -0.066444   -0.056213      -0.062500
# population_household       -0.043553    0.076362   -0.040084      -0.009826
# total_rooms_level          -0.678472   -0.596298   -0.678187      -0.218167
# total_bedrooms_level       -0.728309   -0.636411   -0.720268       0.051043
# median_income_level         0.030144    0.033944    0.054727       0.827746
#
#                       median_house_value  room_household  bedrooms_household  \
# longitude                      -0.044982       -0.032894            0.008413
# latitude                       -0.144917        0.110017            0.073101
# housing_median_age              0.106758       -0.146234           -0.074101
# total_rooms                     0.130991        0.125385            0.024485
# total_bedrooms                  0.045783       -0.006480            0.040284
# population                     -0.027850       -0.074806           -0.066444
# households                      0.061031       -0.084505           -0.056213
# median_income                   0.691871        0.317311           -0.062500
# median_house_value              1.000000        0.150081           -0.045668
# room_household                  0.150081        1.000000            0.853618
# bedrooms_household             -0.045668        0.853618            1.000000
# population_household           -0.042764        0.001476           -0.010405
# total_rooms_level              -0.178247       -0.123594           -0.012750
# total_bedrooms_level           -0.049419        0.036684           -0.032603
# median_income_level             0.587353        0.280094           -0.065487
#
#                       population_household  total_rooms_level  \
# longitude                         0.028951          -0.019190
# latitude                         -0.032784           0.022667
# housing_median_age                0.006274           0.332183
# total_rooms                      -0.035327          -0.697931
# total_bedrooms                   -0.043553          -0.678472
# population                        0.076362          -0.596298
# households                       -0.040084          -0.678187
# median_income                    -0.009826          -0.218167
# median_house_value               -0.042764          -0.178247
# room_household                    0.001476          -0.123594
# bedrooms_household               -0.010405          -0.012750
# population_household              1.000000           0.050888
# total_rooms_level                 0.050888           1.000000
# total_bedrooms_level              0.050488           0.856390
# median_income_level              -0.013441          -0.258866
#
#                       total_bedrooms_level  median_income_level
# longitude                        -0.055218            -0.012903
# latitude                          0.062550            -0.088400
# housing_median_age                0.282761            -0.142548
# total_rooms                      -0.653019             0.224124
# total_bedrooms                   -0.728309             0.030144
# population                       -0.636411             0.033944
# households                       -0.720268             0.054727
# median_income                     0.051043             0.827746
# median_house_value               -0.049419             0.587353
# room_household                    0.036684             0.280094
# bedrooms_household               -0.032603            -0.065487
# population_household              0.050488            -0.013441
# total_rooms_level                 0.856390            -0.258866
# total_bedrooms_level              1.000000             0.001970
# median_income_level               0.001970             1.000000

# %%
train.corr()['median_house_value']
# Out:
# longitude              -0.044982
# latitude               -0.144917
# housing_median_age      0.106758
# total_rooms             0.130991
# total_bedrooms          0.045783
# population             -0.027850
# households              0.061031
# median_income           0.691871
# median_house_value      1.000000
# room_household          0.150081
# bedrooms_household     -0.045668
# population_household   -0.042764
# total_rooms_level      -0.178247
# total_bedrooms_level   -0.049419
# median_income_level     0.587353
# Name: median_house_value, dtype: float64

# %%
train
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
#        population  households  median_income  median_house_value  \
# 0          1015.0       472.0         1.4936             66900.0
# 1          1129.0       463.0         1.8200             80100.0
# 2           333.0       117.0         1.6509             85700.0
# 3           515.0       226.0         3.1917             73400.0
# 4           624.0       262.0         1.9250             65500.0
# ...           ...         ...            ...                 ...
# 16995       907.0       369.0         2.3571            111400.0
# 16996      1194.0       465.0         2.5179             79000.0
# 16997      1244.0       456.0         3.0313            103600.0
# 16998      1298.0       478.0         1.9797             85800.0
# 16999       806.0       270.0         3.0147             94600.0
#
#        room_household  bedrooms_household  population_household  \
# 0           11.889831            2.718220              2.150424
# 1           16.522678            4.105832              2.438445
# 2            6.153846            1.487179              2.846154
# 3            6.641593            1.491150              2.278761
# 4            5.549618            1.244275              2.381679
# ...               ...                 ...                   ...
# 16995        6.008130            1.067751              2.457995
# 16996        5.051613            1.135484              2.567742
# 16997        5.870614            1.164474              2.728070
# 16998        5.589958            1.154812              2.715481
# 16999        6.740741            1.111111              2.985185
#
#        total_rooms_level  total_bedrooms_level  median_income_level
# 0                    1.0                   1.0                  3.0
# 1                    1.0                   1.0                  4.0
# 2                    4.0                   4.0                  4.0
# 3                    3.0                   3.0                  7.0
# 4                    4.0                   3.0                  4.0
# ...                  ...                   ...                  ...
# 16995                2.0                   3.0                  5.0
# 16996                2.0                   2.0                  6.0
# 16997                2.0                   2.0                  7.0
# 16998                2.0                   2.0                  4.0
# 16999                3.0                   3.0                  7.0
#
# [17000 rows x 15 columns]

# %%
train.groupby('total_rooms_level').count()
# Out:
#                    longitude  latitude  housing_median_age  total_rooms  \
# total_rooms_level
# 1.0                     4250      4250                4250         4250
# 2.0                     4247      4247                4247         4247
# 3.0                     4249      4249                4249         4249
# 4.0                     4254      4254                4254         4254
#
#                    total_bedrooms  population  households  median_income  \
# total_rooms_level
# 1.0                          4250        4250        4250           4250
# 2.0                          4247        4247        4247           4247
# 3.0                          4249        4249        4249           4249
# 4.0                          4254        4254        4254           4254
#
#                    median_house_value  room_household  bedrooms_household  \
# total_rooms_level
# 1.0                              4250            4250                4250
# 2.0                              4247            4247                4247
# 3.0                              4249            4249                4249
# 4.0                              4254            4254                4254
#
#                    population_household  total_bedrooms_level  \
# total_rooms_level
# 1.0                                4250                  4250
# 2.0                                4247                  4247
# 3.0                                4249                  4249
# 4.0                                4254                  4254
#
#                    median_income_level
# total_rooms_level
# 1.0                               4250
# 2.0                               4247
# 3.0                               4249
# 4.0                               4254

# %% [markdown]
# # total_rooms의 방의 크기 레벨에 따른 연식은?

# %%
train.groupby('total_rooms_level').mean()['housing_median_age']
# Out:
# total_rooms_level
# 1.0    21.170353
# 2.0    28.872145
# 3.0    31.580137
# 4.0    32.731782
# Name: housing_median_age, dtype: float64

# %%
train.groupby('total_bedrooms_level').mean()['housing_median_age']
# Out:
# total_bedrooms_level
# 1.0    22.274118
# 2.0    28.793055
# 3.0    31.198679
# 4.0    32.075952
# Name: housing_median_age, dtype: float64

# %%
### 
train.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value  room_household  \
# 0      1015.0       472.0         1.4936             66900.0       11.889831
# 1      1129.0       463.0         1.8200             80100.0       16.522678
# 2       333.0       117.0         1.6509             85700.0        6.153846
# 3       515.0       226.0         3.1917             73400.0        6.641593
# 4       624.0       262.0         1.9250             65500.0        5.549618
#
#    bedrooms_household  population_household  total_rooms_level  \
# 0            2.718220              2.150424                1.0
# 1            4.105832              2.438445                1.0
# 2            1.487179              2.846154                4.0
# 3            1.491150              2.278761                3.0
# 4            1.244275              2.381679                4.0
#
#    total_bedrooms_level  median_income_level
# 0                   1.0                  3.0
# 1                   1.0                  4.0
# 2                   4.0                  4.0
# 3                   3.0                  7.0
# 4                   3.0                  4.0

# %%
train.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value', 'room_household', 'bedrooms_household',
#        'population_household', 'total_rooms_level', 'total_bedrooms_level',
#        'median_income_level'],
#       dtype='object')

# %%
#  target : median_house_value
from sklearn.linear_model import LinearRegression

X = train.loc[ : , 'room_household':'median_income_level' ]
y = train['median_house_value']

# %%
model = LinearRegression()
model.fit(X, y)
pred = model.predict(X)
pred
# Out:
# array([ 69753.09996883,  96329.45651459,  91613.00768363, ...,
#        195496.28308353, 100982.43611157, 192617.66993774])
